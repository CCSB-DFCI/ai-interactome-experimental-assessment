# %%
import pandas as pd

from datasets import load_all_orfs

# %%
df = pd.read_csv('../supplementary_tables/functional_predictions_filtered.tsv', sep='\t')
all_orfs = load_all_orfs()
updated = pd.read_csv('../data/external/all_yeast_gene_names_2025-10-07.tsv', 
                      sep='\t')

all_orfs['gene_name_current'] = all_orfs['orf_name'].map(
    updated.set_index('Gene > Systematic Name')['Gene > Standard Name']
)
all_orfs['gene_name_current_full'] = all_orfs['orf_name'].map(
    updated.set_index('Gene > Systematic Name')['Gene > Name']
)
all_orfs['description_current'] = all_orfs['orf_name'].map(
    updated.set_index('Gene > Systematic Name')['Gene > Mod Description']
)

gene_names = all_orfs.dropna(subset=['gene_name']).set_index('orf_name')['gene_name'].to_dict()
gene_names_current = all_orfs.dropna(subset=['gene_name_current']).set_index('orf_name')['gene_name_current'].to_dict()
gene_names_current_full = all_orfs.dropna(subset=['gene_name_current_full']).set_index('orf_name')['gene_name_current_full'].to_dict()
description_current = all_orfs.dropna(subset=['description_current']).set_index('orf_name')['description_current'].to_dict()
df['gene_name'] = df['orf_name'].map(gene_names)
df['gene_name_current'] = df['orf_name'].map(gene_names_current)
df['gene_name_current_full'] = df['orf_name'].map(gene_names_current_full)
df['description_current'] = df['orf_name'].map(description_current)
df['updated_name'] = (df['gene_name_current'].notnull()
                        & (df['gene_name'] != df['gene_name_current']))

# %%
print('\n'.join(df.loc[df['updated_name'],
    'gene_name_current'
].sort_values().unique()))
# Out:
# AAN1
# CAL4
# CSA1
# PEX35
# VPR1

# %%
gene = 'CSA1'
df.loc[(df['gene_name_current'] == gene)
                         & (df['z-score'] > 5)
                         & (df['n_interactors_with_GO_term'] >= 2), 
                         ['GO_ID', 'GO_term_name', 'n_interactors_with_GO_term', 'z-score', 'effect_size', 'dataset', 'n_proteins_with_GO_term_in_network', ]
                         ].sort_values('z-score', ascending=False)
# Out:
#           GO_ID GO_term_name  n_interactors_with_GO_term  z-score  \
# 114  GO:0016021     membrane                           3  6.09698
#
#      effect_size       dataset  n_proteins_with_GO_term_in_network
# 114      1.86202  Y2H-union-25                                  19

# %%
updated_genes = df.loc[df['updated_name'],
    'gene_name_current'
    ].sort_values().unique()
for gene in updated_genes:
    predictions = df.loc[(df['gene_name_current'] == gene)
                         & (df['z-score'] > 5)
                         & (df['n_interactors_with_GO_term'] >= 2)
                         , :].sort_values('z-score', ascending=False)
    if len(predictions) == 0:
        continue
    print()
    print()
    print(gene, '–', df.loc[df['gene_name_current'] == gene, 'gene_name_current_full'].iloc[0])
    print(df.loc[df['gene_name_current'] == gene, 'description_current'].iloc[0])
    print()
    print('Predictions:')
    print(predictions)
# Out:
# AAN1 – Actin, Aging and Nutrient modulator
# Protein of unknown function; regulates actin cable stability and branched-chain amino acid (BCAA) metabolism; involved in mitochondrial quality control and longevity; proposed to be involved in resistance to streptozotocin and camptothecin; localizes to punctate cytosolic structures
#
# Predictions:
#           GO_ID orf_name  n_proteins_with_GO_term_in_network  \
# 132  GO:0034553  YKL075C                                   2
# 36   GO:0034553  YKL075C                                   2
# 60   GO:0000480  YKL075C                                  12
# 75   GO:0003724  YKL075C                                   7
# 58   GO:0000447  YKL075C                                  19
# 83   GO:0005759  YKL075C                                  31
# 18   GO:0005759  YKL075C                                  23
#
#      n_interactors_with_GO_term  mean_in_random_networks  \
# 132                           2                    0.002
# 36                            2                    0.005
# 60                            2                    0.031
# 75                            2                    0.035
# 58                            2                    0.065
# 83                            2                    0.103
# 18                            2                    0.125
#
#      std_in_random_networks  p-value   z-score  effect_size       dataset  \
# 132                0.044677   0.0000  44.72140      1.90865  Y2H-union-25
# 36                 0.070534   0.0000  28.28440      1.85393          YeRI
# 60                 0.173318   0.0000  11.36060      1.62236  Y2H-union-25
# 75                 0.189143   0.0005  10.38900      1.58671  Y2H-union-25
# 58                 0.254509   0.0010   7.60286      1.42598  Y2H-union-25
# 83                 0.313673   0.0015   6.04769      1.26965  Y2H-union-25
# 18                 0.365205   0.0060   5.13410      1.14459          YeRI
#
#                                           GO_term_name gene_name  \
# 132  mitochondrial respiratory chain complex II ass...       NaN
# 36   mitochondrial respiratory chain complex II ass...       NaN
# 60   endonucleolytic cleavage in 5'-ETS of tricistr...       NaN
# 75                               RNA helicase activity       NaN
# 58   endonucleolytic cleavage in ITS1 to separate S...       NaN
# 83                                mitochondrial matrix       NaN
# 18                                mitochondrial matrix       NaN
#
#     gene_name_current               gene_name_current_full  \
# 132              AAN1  Actin, Aging and Nutrient modulator
# 36               AAN1  Actin, Aging and Nutrient modulator
# 60               AAN1  Actin, Aging and Nutrient modulator
# 75               AAN1  Actin, Aging and Nutrient modulator
# 58               AAN1  Actin, Aging and Nutrient modulator
# 83               AAN1  Actin, Aging and Nutrient modulator
# 18               AAN1  Actin, Aging and Nutrient modulator
#
#                                    description_current  updated_name
# 132  Protein of unknown function; regulates actin c...          True
# 36   Protein of unknown function; regulates actin c...          True
# 60   Protein of unknown function; regulates actin c...          True
# 75   Protein of unknown function; regulates actin c...          True
# 58   Protein of unknown function; regulates actin c...          True
# 83   Protein of unknown function; regulates actin c...          True
# 18   Protein of unknown function; regulates actin c...          True
#
#
# CAL4 – Caf130-Associated regulator of RpL4
# Accessory component of the Ccr4-NOT complex; GFP-fusion protein expression is induced in response to the DNA-damaging agent MMS
#
# Predictions:
#           GO_ID orf_name  n_proteins_with_GO_term_in_network  \
# 121  GO:0030015  YJR011C                                   9
# 69   GO:0002098  YJR011C                                  15
# 11   GO:0002098  YJR011C                                  14
#
#      n_interactors_with_GO_term  mean_in_random_networks  \
# 121                           2                    0.073
# 69                            2                    0.123
# 11                            2                    0.131
#
#      std_in_random_networks  p-value  z-score  effect_size       dataset  \
# 121                0.260137    0.000  7.40765      1.40673  Y2H-union-25
# 69                 0.346224    0.003  5.42135      1.18455  Y2H-union-25
# 11                 0.354738    0.003  5.26868      1.15952          YeRI
#
#                          GO_term_name gene_name gene_name_current  \
# 121             CCR4-NOT core complex       NaN              CAL4
# 69   tRNA wobble uridine modification       NaN              CAL4
# 11   tRNA wobble uridine modification       NaN              CAL4
#
#                   gene_name_current_full  \
# 121  Caf130-Associated regulator of RpL4
# 69   Caf130-Associated regulator of RpL4
# 11   Caf130-Associated regulator of RpL4
#
#                                    description_current  updated_name
# 121  Accessory component of the Ccr4-NOT complex; G...          True
# 69   Accessory component of the Ccr4-NOT complex; G...          True
# 11   Accessory component of the Ccr4-NOT complex; G...          True
#
#
# CSA1 – Cdc5 SPB Anchor
# Protein of unknown function; green fluorescent protein (GFP)-fusion protein localizes to the nuclear periphery; potential Cdc28p substrate; binds phosphatidylinositols and phosphatidylethanolamine in a large-scale study; relative distribution to foci at the nuclear periphery increases upon DNA replication stress; YPR174C has a paralog, NBP1, that arose from the whole genome duplication
#
# Predictions:
#           GO_ID orf_name  n_proteins_with_GO_term_in_network  \
# 114  GO:0016021  YPR174C                                  19
#
#      n_interactors_with_GO_term  mean_in_random_networks  \
# 114                           3                    0.229
#
#      std_in_random_networks  p-value  z-score  effect_size       dataset  \
# 114                0.454488      0.0  6.09698      1.86202  Y2H-union-25
#
#     GO_term_name gene_name gene_name_current gene_name_current_full  \
# 114     membrane       NaN              CSA1        Cdc5 SPB Anchor
#
#                                    description_current  updated_name
# 114  Protein of unknown function; green fluorescent...          True
#
#
# PEX35 – PEroXin
# Regulator of peroxisome abundance; peroxisomal membrane protein, remote homolog to several curvature-generating human proteins; functionally interacts with vesicle-budding-inducing ADP-ribosylation factor Arf1p
#
# Predictions:
#           GO_ID orf_name  n_proteins_with_GO_term_in_network  \
# 19   GO:0005778  YGR168C                                   8
# 115  GO:0016558  YGR168C                                  10
# 59   GO:0000461  YGR168C                                   4
# 86   GO:0005779  YGR168C                                   9
# 116  GO:0016559  YGR168C                                   6
# 47   GO:1990429  YGR168C                                   6
# 85   GO:0005778  YGR168C                                  13
# 29   GO:0016559  YGR168C                                   5
# 155  GO:1990429  YGR168C                                   8
# 84   GO:0005770  YGR168C                                  13
# 105  GO:0007031  YGR168C                                  13
# 27   GO:0007031  YGR168C                                   8
# 28   GO:0016558  YGR168C                                   6
#
#      n_interactors_with_GO_term  mean_in_random_networks  \
# 19                            3                    0.152
# 115                           2                    0.077
# 59                            2                    0.076
# 86                            2                    0.086
# 116                           2                    0.103
# 47                            2                    0.099
# 85                            3                    0.199
# 29                            2                    0.099
# 155                           2                    0.097
# 84                            2                    0.112
# 105                           3                    0.262
# 27                            3                    0.257
# 28                            2                    0.117
#
#      std_in_random_networks  p-value  z-score  effect_size       dataset  \
# 19                 0.375361   0.0000  7.58736      2.09728          YeRI
# 115                0.277617   0.0015  6.92682      1.36777  Y2H-union-25
# 59                 0.283238   0.0025  6.79286      1.35752  Y2H-union-25
# 86                 0.287409   0.0010  6.65950      1.33918  Y2H-union-25
# 116                0.307231   0.0005  6.17450      1.28254  Y2H-union-25
# 47                 0.308543   0.0015  6.16121      1.28391          YeRI
# 85                 0.459781   0.0010  6.09202      1.88144  Y2H-union-25
# 29                 0.314959   0.0025  6.03571      1.27108          YeRI
# 155                0.321856   0.0040  5.91259      1.25929  Y2H-union-25
# 84                 0.327805   0.0020  5.75952      1.23239  Y2H-union-25
# 105                0.487192   0.0005  5.61996      1.76362  Y2H-union-25
# 27                 0.494925   0.0000  5.54225      1.75315          YeRI
# 28                 0.345414   0.0040  5.45143      1.19217          YeRI
#
#                                           GO_term_name gene_name  \
# 19                                peroxisomal membrane       NaN
# 115              protein import into peroxisome matrix       NaN
# 59   endonucleolytic cleavage to generate mature 3'...       NaN
# 86          integral component of peroxisomal membrane       NaN
# 116                                 peroxisome fission       NaN
# 47                      peroxisomal importomer complex       NaN
# 85                                peroxisomal membrane       NaN
# 29                                  peroxisome fission       NaN
# 155                     peroxisomal importomer complex       NaN
# 84                                       late endosome       NaN
# 105                            peroxisome organization       NaN
# 27                             peroxisome organization       NaN
# 28               protein import into peroxisome matrix       NaN
#
#     gene_name_current gene_name_current_full  \
# 19              PEX35                PEroXin
# 115             PEX35                PEroXin
# 59              PEX35                PEroXin
# 86              PEX35                PEroXin
# 116             PEX35                PEroXin
# 47              PEX35                PEroXin
# 85              PEX35                PEroXin
# 29              PEX35                PEroXin
# 155             PEX35                PEroXin
# 84              PEX35                PEroXin
# 105             PEX35                PEroXin
# 27              PEX35                PEroXin
# 28              PEX35                PEroXin
#
#                                    description_current  updated_name
# 19   Regulator of peroxisome abundance; peroxisomal...          True
# 115  Regulator of peroxisome abundance; peroxisomal...          True
# 59   Regulator of peroxisome abundance; peroxisomal...          True
# 86   Regulator of peroxisome abundance; peroxisomal...          True
# 116  Regulator of peroxisome abundance; peroxisomal...          True
# 47   Regulator of peroxisome abundance; peroxisomal...          True
# 85   Regulator of peroxisome abundance; peroxisomal...          True
# 29   Regulator of peroxisome abundance; peroxisomal...          True
# 155  Regulator of peroxisome abundance; peroxisomal...          True
# 84   Regulator of peroxisome abundance; peroxisomal...          True
# 105  Regulator of peroxisome abundance; peroxisomal...          True
# 27   Regulator of peroxisome abundance; peroxisomal...          True
# 28   Regulator of peroxisome abundance; peroxisomal...          True
#
#
# VPR1 – Viable Products in spp1∆ meiosis Reduced
# Protein of unknown function
#
# Predictions:
#           GO_ID orf_name  n_proteins_with_GO_term_in_network  \
# 152  GO:0097196  YIL152W                                   4
# 63   GO:0000730  YIL152W                                   6
# 62   GO:0000725  YIL152W                                   8
# 5    GO:0000725  YIL152W                                   5
# 44   GO:0097196  YIL152W                                   4
# 7    GO:0000730  YIL152W                                   6
# 133  GO:0043007  YIL152W                                   7
#
#      n_interactors_with_GO_term  mean_in_random_networks  \
# 152                           3                    0.033
# 63                            3                    0.040
# 62                            3                    0.059
# 5                             2                    0.039
# 44                            2                    0.039
# 7                             2                    0.049
# 133                           2                    0.056
#
#      std_in_random_networks  p-value   z-score  effect_size       dataset  \
# 152                0.178637   0.0000  16.60910      2.60973  Y2H-union-25
# 63                 0.195959   0.0000  15.10520      2.56808  Y2H-union-25
# 62                 0.235625   0.0000  12.48170      2.46975  Y2H-union-25
# 5                  0.198693   0.0005   9.86949      1.56361          YeRI
# 44                 0.198693   0.0005   9.86949      1.56361          YeRI
# 7                  0.229345   0.0015   8.50685      1.49231          YeRI
# 133                0.238462   0.0010   8.15225      1.46708  Y2H-union-25
#
#                  GO_term_name gene_name gene_name_current  \
# 152               Shu complex       NaN              VPR1
# 63   DNA recombinase assembly       NaN              VPR1
# 62     recombinational repair       NaN              VPR1
# 5      recombinational repair       NaN              VPR1
# 44                Shu complex       NaN              VPR1
# 7    DNA recombinase assembly       NaN              VPR1
# 133       maintenance of rDNA       NaN              VPR1
#
#                        gene_name_current_full          description_current  \
# 152  Viable Products in spp1∆ meiosis Reduced  Protein of unknown function
# 63   Viable Products in spp1∆ meiosis Reduced  Protein of unknown function
# 62   Viable Products in spp1∆ meiosis Reduced  Protein of unknown function
# 5    Viable Products in spp1∆ meiosis Reduced  Protein of unknown function
# 44   Viable Products in spp1∆ meiosis Reduced  Protein of unknown function
# 7    Viable Products in spp1∆ meiosis Reduced  Protein of unknown function
# 133  Viable Products in spp1∆ meiosis Reduced  Protein of unknown function
#
#      updated_name
# 152          True
# 63           True
# 62           True
# 5            True
# 44           True
# 7            True
# 133          True

# %%
df.loc[df['updated_name'], 'description_current'].value_counts()
# Out:
# Regulator of peroxisome abundance; peroxisomal membrane protein, remote homolog to several curvature-generating human proteins; functionally interacts with vesicle-budding-inducing ADP-ribosylation factor Arf1p                                                                                                                                                                                      13
# Protein of unknown function                                                                                                                                                                                                                                                                                                                                                                              7
# Protein of unknown function; regulates actin cable stability and branched-chain amino acid (BCAA) metabolism; involved in mitochondrial quality control and longevity; proposed to be involved in resistance to streptozotocin and camptothecin; localizes to punctate cytosolic structures                                                                                                              7
# Accessory component of the Ccr4-NOT complex; GFP-fusion protein expression is induced in response to the DNA-damaging agent MMS                                                                                                                                                                                                                                                                          3
# Protein of unknown function; green fluorescent protein (GFP)-fusion protein localizes to the nuclear periphery; potential Cdc28p substrate; binds phosphatidylinositols and phosphatidylethanolamine in a large-scale study; relative distribution to foci at the nuclear periphery increases upon DNA replication stress; YPR174C has a paralog, NBP1, that arose from the whole genome duplication     1
# Name: description_current, dtype: int64

# %%
df.loc[df['updated_name']].sort_values(['gene_name_current', 'z-score'], ascending=[True, False])
# Out:
#           GO_ID orf_name  n_proteins_with_GO_term_in_network  \
# 132  GO:0034553  YKL075C                                   2
# 36   GO:0034553  YKL075C                                   2
# 60   GO:0000480  YKL075C                                  12
# 75   GO:0003724  YKL075C                                   7
# 58   GO:0000447  YKL075C                                  19
# 83   GO:0005759  YKL075C                                  31
# 18   GO:0005759  YKL075C                                  23
# 121  GO:0030015  YJR011C                                   9
# 69   GO:0002098  YJR011C                                  15
# 11   GO:0002098  YJR011C                                  14
# 114  GO:0016021  YPR174C                                  19
# 19   GO:0005778  YGR168C                                   8
# 115  GO:0016558  YGR168C                                  10
# 59   GO:0000461  YGR168C                                   4
# 86   GO:0005779  YGR168C                                   9
# 116  GO:0016559  YGR168C                                   6
# 47   GO:1990429  YGR168C                                   6
# 85   GO:0005778  YGR168C                                  13
# 29   GO:0016559  YGR168C                                   5
# 155  GO:1990429  YGR168C                                   8
# 84   GO:0005770  YGR168C                                  13
# 105  GO:0007031  YGR168C                                  13
# 27   GO:0007031  YGR168C                                   8
# 28   GO:0016558  YGR168C                                   6
# 152  GO:0097196  YIL152W                                   4
# 63   GO:0000730  YIL152W                                   6
# 62   GO:0000725  YIL152W                                   8
# 5    GO:0000725  YIL152W                                   5
# 44   GO:0097196  YIL152W                                   4
# 7    GO:0000730  YIL152W                                   6
# 133  GO:0043007  YIL152W                                   7
#
#      n_interactors_with_GO_term  mean_in_random_networks  \
# 132                           2                    0.002
# 36                            2                    0.005
# 60                            2                    0.031
# 75                            2                    0.035
# 58                            2                    0.065
# 83                            2                    0.103
# 18                            2                    0.125
# 121                           2                    0.073
# 69                            2                    0.123
# 11                            2                    0.131
# 114                           3                    0.229
# 19                            3                    0.152
# 115                           2                    0.077
# 59                            2                    0.076
# 86                            2                    0.086
# 116                           2                    0.103
# 47                            2                    0.099
# 85                            3                    0.199
# 29                            2                    0.099
# 155                           2                    0.097
# 84                            2                    0.112
# 105                           3                    0.262
# 27                            3                    0.257
# 28                            2                    0.117
# 152                           3                    0.033
# 63                            3                    0.040
# 62                            3                    0.059
# 5                             2                    0.039
# 44                            2                    0.039
# 7                             2                    0.049
# 133                           2                    0.056
#
#      std_in_random_networks  p-value   z-score  effect_size       dataset  \
# 132                0.044677   0.0000  44.72140      1.90865  Y2H-union-25
# 36                 0.070534   0.0000  28.28440      1.85393          YeRI
# 60                 0.173318   0.0000  11.36060      1.62236  Y2H-union-25
# 75                 0.189143   0.0005  10.38900      1.58671  Y2H-union-25
# 58                 0.254509   0.0010   7.60286      1.42598  Y2H-union-25
# 83                 0.313673   0.0015   6.04769      1.26965  Y2H-union-25
# 18                 0.365205   0.0060   5.13410      1.14459          YeRI
# 121                0.260137   0.0000   7.40765      1.40673  Y2H-union-25
# 69                 0.346224   0.0030   5.42135      1.18455  Y2H-union-25
# 11                 0.354738   0.0030   5.26868      1.15952          YeRI
# 114                0.454488   0.0000   6.09698      1.86202  Y2H-union-25
# 19                 0.375361   0.0000   7.58736      2.09728          YeRI
# 115                0.277617   0.0015   6.92682      1.36777  Y2H-union-25
# 59                 0.283238   0.0025   6.79286      1.35752  Y2H-union-25
# 86                 0.287409   0.0010   6.65950      1.33918  Y2H-union-25
# 116                0.307231   0.0005   6.17450      1.28254  Y2H-union-25
# 47                 0.308543   0.0015   6.16121      1.28391          YeRI
# 85                 0.459781   0.0010   6.09202      1.88144  Y2H-union-25
# 29                 0.314959   0.0025   6.03571      1.27108          YeRI
# 155                0.321856   0.0040   5.91259      1.25929  Y2H-union-25
# 84                 0.327805   0.0020   5.75952      1.23239  Y2H-union-25
# 105                0.487192   0.0005   5.61996      1.76362  Y2H-union-25
# 27                 0.494925   0.0000   5.54225      1.75315          YeRI
# 28                 0.345414   0.0040   5.45143      1.19217          YeRI
# 152                0.178637   0.0000  16.60910      2.60973  Y2H-union-25
# 63                 0.195959   0.0000  15.10520      2.56808  Y2H-union-25
# 62                 0.235625   0.0000  12.48170      2.46975  Y2H-union-25
# 5                  0.198693   0.0005   9.86949      1.56361          YeRI
# 44                 0.198693   0.0005   9.86949      1.56361          YeRI
# 7                  0.229345   0.0015   8.50685      1.49231          YeRI
# 133                0.238462   0.0010   8.15225      1.46708  Y2H-union-25
#
#                                           GO_term_name gene_name  \
# 132  mitochondrial respiratory chain complex II ass...       NaN
# 36   mitochondrial respiratory chain complex II ass...       NaN
# 60   endonucleolytic cleavage in 5'-ETS of tricistr...       NaN
# 75                               RNA helicase activity       NaN
# 58   endonucleolytic cleavage in ITS1 to separate S...       NaN
# 83                                mitochondrial matrix       NaN
# 18                                mitochondrial matrix       NaN
# 121                              CCR4-NOT core complex       NaN
# 69                    tRNA wobble uridine modification       NaN
# 11                    tRNA wobble uridine modification       NaN
# 114                                           membrane       NaN
# 19                                peroxisomal membrane       NaN
# 115              protein import into peroxisome matrix       NaN
# 59   endonucleolytic cleavage to generate mature 3'...       NaN
# 86          integral component of peroxisomal membrane       NaN
# 116                                 peroxisome fission       NaN
# 47                      peroxisomal importomer complex       NaN
# 85                                peroxisomal membrane       NaN
# 29                                  peroxisome fission       NaN
# 155                     peroxisomal importomer complex       NaN
# 84                                       late endosome       NaN
# 105                            peroxisome organization       NaN
# 27                             peroxisome organization       NaN
# 28               protein import into peroxisome matrix       NaN
# 152                                        Shu complex       NaN
# 63                            DNA recombinase assembly       NaN
# 62                              recombinational repair       NaN
# 5                               recombinational repair       NaN
# 44                                         Shu complex       NaN
# 7                             DNA recombinase assembly       NaN
# 133                                maintenance of rDNA       NaN
#
#     gene_name_current                    gene_name_current_full  \
# 132              AAN1       Actin, Aging and Nutrient modulator
# 36               AAN1       Actin, Aging and Nutrient modulator
# 60               AAN1       Actin, Aging and Nutrient modulator
# 75               AAN1       Actin, Aging and Nutrient modulator
# 58               AAN1       Actin, Aging and Nutrient modulator
# 83               AAN1       Actin, Aging and Nutrient modulator
# 18               AAN1       Actin, Aging and Nutrient modulator
# 121              CAL4       Caf130-Associated regulator of RpL4
# 69               CAL4       Caf130-Associated regulator of RpL4
# 11               CAL4       Caf130-Associated regulator of RpL4
# 114              CSA1                           Cdc5 SPB Anchor
# 19              PEX35                                   PEroXin
# 115             PEX35                                   PEroXin
# 59              PEX35                                   PEroXin
# 86              PEX35                                   PEroXin
# 116             PEX35                                   PEroXin
# 47              PEX35                                   PEroXin
# 85              PEX35                                   PEroXin
# 29              PEX35                                   PEroXin
# 155             PEX35                                   PEroXin
# 84              PEX35                                   PEroXin
# 105             PEX35                                   PEroXin
# 27              PEX35                                   PEroXin
# 28              PEX35                                   PEroXin
# 152              VPR1  Viable Products in spp1∆ meiosis Reduced
# 63               VPR1  Viable Products in spp1∆ meiosis Reduced
# 62               VPR1  Viable Products in spp1∆ meiosis Reduced
# 5                VPR1  Viable Products in spp1∆ meiosis Reduced
# 44               VPR1  Viable Products in spp1∆ meiosis Reduced
# 7                VPR1  Viable Products in spp1∆ meiosis Reduced
# 133              VPR1  Viable Products in spp1∆ meiosis Reduced
#
#                                    description_current  updated_name
# 132  Protein of unknown function; regulates actin c...          True
# 36   Protein of unknown function; regulates actin c...          True
# 60   Protein of unknown function; regulates actin c...          True
# 75   Protein of unknown function; regulates actin c...          True
# 58   Protein of unknown function; regulates actin c...          True
# 83   Protein of unknown function; regulates actin c...          True
# 18   Protein of unknown function; regulates actin c...          True
# 121  Accessory component of the Ccr4-NOT complex; G...          True
# 69   Accessory component of the Ccr4-NOT complex; G...          True
# 11   Accessory component of the Ccr4-NOT complex; G...          True
# 114  Protein of unknown function; green fluorescent...          True
# 19   Regulator of peroxisome abundance; peroxisomal...          True
# 115  Regulator of peroxisome abundance; peroxisomal...          True
# 59   Regulator of peroxisome abundance; peroxisomal...          True
# 86   Regulator of peroxisome abundance; peroxisomal...          True
# 116  Regulator of peroxisome abundance; peroxisomal...          True
# 47   Regulator of peroxisome abundance; peroxisomal...          True
# 85   Regulator of peroxisome abundance; peroxisomal...          True
# 29   Regulator of peroxisome abundance; peroxisomal...          True
# 155  Regulator of peroxisome abundance; peroxisomal...          True
# 84   Regulator of peroxisome abundance; peroxisomal...          True
# 105  Regulator of peroxisome abundance; peroxisomal...          True
# 27   Regulator of peroxisome abundance; peroxisomal...          True
# 28   Regulator of peroxisome abundance; peroxisomal...          True
# 152                        Protein of unknown function          True
# 63                         Protein of unknown function          True
# 62                         Protein of unknown function          True
# 5                          Protein of unknown function          True
# 44                         Protein of unknown function          True
# 7                          Protein of unknown function          True
# 133                        Protein of unknown function          True

# %%
df.loc[df['updated_name']].sort_values(['gene_name_current', 'z-score'], ascending=[True, False]).to_csv(
    '../output/functional_predictions_with_names.tsv', sep='\t', index=False
)
